# %%
# %load_ext autoreload
# %autoreload 2

# %%
from tools.utils import helper_autoloader
from tools.config import *

# %%
for k, v in SOURCES.items():
    helper_autoloader(
        spark_session = spark,
        input_path = v,
        target_tbl = BRONZE_TABLES[k],
        checkpoint_loc = f"{CHECKPOINTS_ROOT}/{SCHEMA_BRONZE}/{k}/_chkpt",
        schema_loc = f"{CHECKPOINTS_ROOT}/{SCHEMA_BRONZE}/{k}/_schema",
        file_type = "csv",
        header = True,
        multi_line = False,
        metadata = True,
    )
