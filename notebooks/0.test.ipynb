# %%
# %sql
DROP TABLE ecom_lakehouse.bronze.customers;
DROP TABLE ecom_lakehouse.bronze.customers;

# %%
from tools.utils import helper_autoloader

# %%
helper_autoloader(
    spark_session=spark,
    input_path="customers",
    output_table="customers",
    file_type="csv",
    schema_name="bronze",
    header=True,
    multi_line=False,
    metadata=True
)

# %%
spark.sql("SELECT * FROM ecom_lakehouse.bronze.customers").display()
