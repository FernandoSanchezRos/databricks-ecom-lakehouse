# %%
from tools.config import (CATALOG, SCHEMA_BRONZE, BRONZE_TABLES)

# %%
spark.sql(f"USE CATALOG {CATALOG}")
spark.sql(f"USE SCHEMA {SCHEMA_BRONZE}")

# %%
for k, v in BRONZE_TABLES.items():
    spark.sql(f"CREATE TABLE IF NOT EXISTS {v} USING DELTA")
